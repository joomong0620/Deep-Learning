# %% [markdown]
# ## 01. 미분
#
#
# 미분의 기본 개념은 함수의 변화율을 구하는 데 있다. 이는 함수가 입력의 변화에 따라 얼마나 변하는지를 수학적으로 분석하는 도구이다.
#
#
# ### 01-01. 평균 변화율
#
#
# 먼저, 함수 $f(x)$의 **평균 변화율**을 살펴본다. 이는 두 점 $x$와 $x + h$ 사이에서 함수 $f(x)$가 얼마나 변했는지를 나타내는 지표이다.
#
#
# $$
# 평균변화율 = \frac{f(x + h) − f(x)}{h}
# $$
#
#
# 예를 들어, $f(x) = 2x$라 할 때, $x=5$에서 $x=8$로 바뀌었다고 하면, 평균 변화율은 다음과 같다.
#
#
# $$
# \frac{f(8) - f(5)}{3} = \frac{16 - 10}{3} = 2
# $$
#
#
# 이는 $h$만큼의 변화에 대해 함수 $f$가 얼마나 변하는지를 나타내며, 기울기의 개념과도 연결된다.
#
#
# ### 01-02. 순간 변화율 (미분의 정의)
#
#
# **순간 변화율**은 평균 변화율에서 $h$가 0에 극한으로 가까워질 때를 의미한다. 이를 통해 미분을 정의할 수 있다.
#
#
# $$
# f′(x) = \lim_{h→0}\frac{f(x + h) − f(x)}{h}
# $$
#
#
# **예: $f(x) = x^2$의 미분**
#
#
# $$
# \frac{(x + h)^2 − x^2}{h} = \frac{x^2 + 2xh + h^2 − x^2}{h} = \frac{2xh + h^2}{h} = 2x + h
# $$
#
#
# 극한을 취하면 다음과 같다.
#
#
# $$
# \lim_{h → 0}(2x + h) = 2x
# $$
#
#
# 따라서, $f(x) = x^2$의 미분은 $f′(x) = 2x$이다.
#
#
# ### 01-03. 다양한 미분 예시
#
#
# #### 01-03-01. 다항 함수 $f(x) = x^2$
#
#
# 위와 같이 전개 및 극한을 통해 다음을 얻는다.
#
#
# $$
# f′(x) = 2x
# $$
#
#
# #### 01-03-02. 상수 함수 $f(x) = c$
#
#
# $$
# \frac{f(x + h) − f(x)}{h} = \frac{c − c}{h} = 0
# $$
#
#
# 상수 함수는 입력 변화에 관계없이 값이 일정하므로 미분값은 항상 0이다.
#
#
# $$
# f′(x) = 0
# $$
#
#
# #### 01-03-03. 선형 함수 $f(x) = mx + b$
#
#
# $$
# \frac{f(x + h) − f(x)}{h} = \frac{m(x + h) + b − (mx + b)}{h} = \frac{mh}{h} = m
# $$
#
#
# 따라서, 선형 함수의 미분은 $f′(x) = m$이다.
#
#
# ### 01-04. 미분의 기본 규칙
#
#
# 1. 상수 $c$의 미분은 $0$이다.
# 2. $f(x) = x^n$ 형태의 미분은 $nx^{n−1}$이다.
# 3. 함수의 선형 조합 $af(x) + bg(x)$의 미분은 $af′(x) + bg′(x)$이다.
#
#
# ### 01-05. 미분 표기
#
#
# 라이프니츠는 미분을 다음과 같은 표기로 정의하였다:
#
#
# * $d$: differential, 미소한 변화
# * $dx$: $x$의 미소 변화
# * $\frac{d}{dx}$: $x$에 대한 미분 연산자
#
#
# **연쇄 법칙 표기**
#
#
# 합성 함수 $z = f(g(x))$에 대해 다음과 같이 연쇄법칙을 적용할 수 있다:
#
#
# $$
# \frac{dz}{dx} = \frac{dz}{dy} \cdot \frac{dy}{dx}
# $$
#
#
# ### 01-06. 미분의 연쇄 법칙
#
#
# 합성 함수 $y = f(g(x))$의 미분은 내부 함수와 외부 함수의 미분을 곱하여 구한다.
#
#
# * $y = f(u)$
# * $u = g(x)$
#
#
# 이때:
#
#
# $$
# \frac{dy}{dx} = \frac{dy}{du} \cdot \frac{du}{dx}
# $$
#
#
# **예시**
#
#
# $z = y^2$, $y = 5x + 2$인 경우,
#
#
# $$
# \frac{dz}{dx} = \frac{dz}{dy} \cdot \frac{dy}{dx} = 2y \cdot 5 = 10y
# $$
#
#
# $y = 5x + 2$이므로:
#
#
# $$
# \frac{dz}{dx} = 10(5x + 2) = 50x + 20
# $$
#
#
# 이는 직접 미분한 결과와 동일하다.

# %% [markdown]
# ## 02. 미분과 수치미분 개념
#
#
# **수학적 미분 (Analytical Differentiation)**
#
#
# $$
# f(x) = x^2 \Rightarrow f'(x) = 2x
# $$
#
#
# * 수학적으로 정확한 **도함수**를 구함
# * 함수의 변화율을 계산하는 공식 기반 미분
#
#
# **수치미분 (Numerical Differentiation)**
# $$
# f'(x) \approx \frac{f(x+h) - f(x-h)}{2h}
# $$
# * 도함수를 직접 구하지 않고, **근사값으로 기울기를 계산**
# * 여기서 $h$는 아주 작은 수 (예: $h = 1e-4$)
# * 실제 계산 과정을 코드로 볼 수 있어 **직관적**
#
#
# **미분 vs 수치미분 비교표**
#
#
# | 항목    | 수학적 미분 (Analytical) | 수치미분 (Numerical)          |
# | ----- | ------------------- | ------------------------- |
# | 정의 방식 | 공식에 따라 도함수 계산       | 근사값으로 기울기 계산              |
# | 정확도   | 매우 정확함              | 근사값, 오차 발생 가능             |
# | 속도    | 빠름                  | 느림 (함수값 여러 번 계산 필요)       |
# | 용도    | 모델 학습, 역전파 계산       | 디버깅, 검증용 (Gradient Check) |
#
#
# **수치미분 방식비교**
#
#
# > 중앙차분(Central Difference) 방식이 가장 보편적으로 사용된다.
#
#
# | 방식   | 수식                                           | 정확도    | 계산 비용 | 특징         |
# | ---- | -------------------------------------------- | ------ | ----- | ---------- |
# | 전진차분 | $f'(x) \approx \frac{f(x+h) - f(x)}{h}$    | 1차 정확도 | 낮음    | 간단하지만 오차 큼 |
# | 후진차분 | $f'(x) \approx \frac{f(x) - f(x-h)}{h}$    | 1차 정확도 | 낮음    | 전진과 비슷     |
# | 중앙차분 | $f'(x) \approx \frac{f(x+h) - f(x-h)}{2h}$ | 2차 정확도 | 높음    | 정확하고 균형잡힘  |

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

# %%
def f(x) :
    return x ** 2

# 수학적 미분
def df(x) :
    return 2 * x

# 수치미분(중앙차분)
def nummerical_diff(x, h=1e-4) :
    return (f(x + h) - f(x - h)) / (2 * h)

# 전진차분
def nummerical_diff_forward(x, h=1e-4) :
    return (f(x + h) - f(x)) / h

# 후진차분
def nummerical_diff_backward(x, h=1e-4) :
    return (f(x) - f(x - h)) / h

x = np.array(4)
print(f(x))
print(df(x)) # x에 따른 f(x) 순간 기울기 (미분한 값)
print(nummerical_diff(x))
print(nummerical_diff_forward(x))
print(nummerical_diff_backward(x))
# Out:
# 16
# 8
# 7.999999999999119
# 8.00009999998963
# 7.9999000000086085

# %% [markdown]
# ## 03. pyTorch의 자동미분

# %%
# 연산을 시작하는 텐서
x = torch.tensor(4. , requires_grad=True)
# y = f(x) # x ** 2
y = x ** 2

print(y)
print(y.grad_fn) # tensor 연산기록 객체, 직접 실행 불가. 나 무슨무슨 계산 했어요~
y.backward() # 미분(기울기) 계산이 거꾸로 처리, 계산 결과는 x.grad 속성에 저장

print(x.grad)
# Out:
# tensor(16., grad_fn=<PowBackward0>)
# <PowBackward0 object at 0x0000024E98337DC0>
# tensor(8.)

# %%
# 복잡한 연산
x = torch.tensor([4.0], requires_grad=True) # 리프텐서(연관그래프 시작점) 미분대상
y = (x * 3 + 5) ** 2
print(y)

print(y.grad_fn)
print(y.grad_fn.next_functions)

# 연산그래프 추적 함수
def print_grad_fn_tree(fn, indent=0) :
    # 재귀함수 종료 조건
    if fn is None :
        return

    print(' ' * indent + f'└{fn.__class__.__name__}')

    if hasattr(fn, 'next_functions') :
        for sub, _ in fn.next_functions :
            print_grad_fn_tree(sub, indent + 4)

print_grad_fn_tree(y.grad_fn ) # y = (x * 3 + 5) ** 2

y.backward()
print(x.grad)
# Out:
# tensor([289.], grad_fn=<PowBackward0>)
# <PowBackward0 object at 0x0000024E86189B70>
# ((<AddBackward0 object at 0x0000024E9842F130>, 0),)
# └PowBackward0
#     └AddBackward0
#         └MulBackward0
#             └AccumulateGrad
# tensor([102.])

# %% [markdown]
# ## 04. 다변수함수 미분(편미분)

# %%
# 다변수 미분
def f(x, y) :
    return x ** 2 + y ** 2

# (도함수) f에 대한 x편미분  # 빵
def df_dx(x, y) :
    return 2 * x
# (도함수) f에 대한 y편미분 # 딸기라떼
def df_dy(x, y) :
    return 2 * y

# 수치미분 # 도함수를 이용한 게 아니라 근사값 갖고 하는 것
def numerical_partial_diff(f, x, y, var='x', h=1e-4) :
    if var == 'x' :
        return (f(x + h, y) - f(x - h, y)) / (2 * h)
    else :
        return (f(x, y + h) - f(x, y - h)) / (2 * h)


print(f(3, 4))
print('df_dx : ', df_dx(3, 4))
print('df_dy : ', df_dy(3, 4))

print('x에 대한 수치편미분 : ', numerical_partial_diff(f, 3, 4, var='x'))
print('y에 대한 수치편미분 : ', numerical_partial_diff(f, 3, 4, var='y'))
# Out:
# 25
# df_dx :  6
# df_dy :  8
# x에 대한 수치편미분 :  6.00000000000378
# y에 대한 수치편미분 :  7.999999999999119

# %%
# torch 자동미분
x = torch.tensor(3., requires_grad=True)
y = torch.tensor(4., requires_grad=True)

z = f(x, y) # x ** 2 + y ** 2
print(z) # tensor(25., grad_fn=<AddBackward0>)
print_grad_fn_tree(z.grad_fn)

z.backward() # 옵션 틀어놓고 백워드만 하면 결과값 동일하게 얻을 수 있고 연산 그래프 추적도 가능하다.
print(x.grad.item())
print(y.grad.item())
# Out:
# tensor(25., grad_fn=<AddBackward0>)
# └AddBackward0
#     └PowBackward0
#         └AccumulateGrad
#     └PowBackward0
#         └AccumulateGrad
# 6.0
# 8.0

# %% [markdown]
# # 선형층

# %% [markdown]
# * 입력: $x$ (고정)
# * 실제 정답: $y$ (고정)
# * 예측: $\hat{y} = wx + b$
# * 손실: $L = (\hat{y} - y)^2 = (wx + b - y)^2$
#
#
#
#
# 즉, 손실 함수를
#
#
# $$
# L(w, b) = (wx + b - y)^2
# $$
#
#
# 로 보고, $w$와 $b$에 대해 편미분한다.
#
#
# **수학적 미분**
#
#
# $$
# \frac{\partial L}{\partial w} = 2(wx + b - y) \cdot x \\
# $$
# $$
# \frac{\partial L}{\partial b} = 2(wx + b - y)
# $$

# %%
# 선형층 + 손실 함수 구현
def L(w, x, b, y) :
    y_hat = w * x + b
    loss = (y_hat - y) ** 2
    return loss

def dl_dw(w, x, b, y) :
    return 2 * (w * x + b - y) * x

def dl_db(w, x, b, y) :
    return 2 * (w * x + b - y)

# x, y : 지도학습에 제공된 값(고정)
# w, b : 모델이 학습할 가중치/절편 (미분대상)
w, x, b, y = 2.0, 3.0, 1.0, 10.0

print(L(w, x, b, y))
print('L을 w로 편미분 : ', dl_dw(w, x, b, y))
print('L을 b로 편미분 : ', dl_db(w, x, b, y))
# Out:
# 9.0
# L을 w로 편미분 :  -18.0
# L을 b로 편미분 :  -6.0

# %%
# torch
x = torch.tensor(3.0)
y = torch.tensor(10.0)
w = torch.tensor(2.0, requires_grad=True) # 미분을 하려면 이 요소가 꼭 필요해용
b = torch.tensor(1.0, requires_grad=True) # 기존에는 이 코드를 작성한적이 없는데, 기본적으로는 내부적으로 다 돌아갑니당 실습해보기 위해 직접 작성하는거에욥

loss = L(w, x, b, y)
print(loss)

loss.backward()
print('L을 w로 편미분 : ', w.grad.item())
print('L를 b로 편미분 : ', b.grad.item())
print(x.grad)
print(y.grad)
# Out:
# tensor(9., grad_fn=<PowBackward0>)
# L을 w로 편미분 :  -18.0
# L를 b로 편미분 :  -6.0
# None
# None

# %% [markdown]
# ## 06.벡터/행렬 형태
#
#
# * 예측 함수: $\hat{y} = \mathbf{w}^\top \mathbf{x} + b$
# * 손실 함수: $L = (\hat{y} - y)^2$
# * 가중치 벡터 $\mathbf{w}$에 대한 편미분
# * NumPy 및 PyTorch 코드 비교
#
#
# **목표**
#
#
# $$
# \hat{y} = \mathbf{w}^\top \mathbf{x} + b \\
# L = (\hat{y} - y)^2 = (\mathbf{w}^\top \mathbf{x} + b - y)^2
# $$
#
#
# * $\mathbf{x}$: 입력 벡터 (예: 특징 3개짜리 입력)
# * $\mathbf{w}$: 가중치 벡터
# * $b$: 편향
# * $y$: 정답 (스칼라)
#
#
# **수학적으로 편미분**
#
#
# 손실 함수:
#
#
# $$
# L(\mathbf{w}, b) = (\mathbf{w}^\top \mathbf{x} + b - y)^2
# $$
#
#
# 1. $\frac{\partial L}{\partial \mathbf{w}}$
#
#
# $$
# \frac{\partial L}{\partial \mathbf{w}} = 2(\mathbf{w}^\top \mathbf{x} + b - y) \cdot \mathbf{x}
# $$
#
#
# 2. $\frac{\partial L}{\partial b}$
#
#
# $$
# \frac{\partial L}{\partial b} = 2(\mathbf{w}^\top \mathbf{x} + b - y)
# $$

# %%
# 벡터/행렬형태의 선형층 + 손실함수
X = np.array([[1., 2., 3.], [4., 5., 6.]]) # (2, 3)
y = np.array([2.])
W = np.array([[0.1, 0.2, 0.3]]) # (1, 3)
b = np.array([0.5])

def L(W, X, b, y) :
    y_hat = X @ W.T + b
    loss = (y_hat - y) ** 2
    return np.mean(loss)

def dl_dW(W, X, b, y) :
    y_hat = X @ W.T + b
    return np.mean(2 * (y_hat - y) * X, axis=0)

def dl_db(W, X, b, y) :
    y_hat = X @ W.T + b
    return np.mean(2 * (y_hat - y), axis=0)

print(L(W, X, b, y))
print('L에 대한 W편미분 : ', dl_dW(W, X, b, y))
print('L에 대한 b편미분 : ', dl_db(W, X, b, y))
# Out:
# 1.4499999999999997
# L에 대한 W편미분 :  [6.7 8.3 9.9]
# L에 대한 b편미분 :  [1.6]

# %%
# 자동미분
X = torch.tensor([[1., 2., 3.], [4., 5., 6.]]) # (2, 3)
y = torch.tensor([2.])
W = torch.tensor([[0.1, 0.2, 0.3]], requires_grad=True) # (1, 3)
b = torch.tensor([0.5], requires_grad=True)

def L(W, X, b, y) :
    y_hat = X @ W.T + b
    loss = (y_hat - y) ** 2
    return torch.mean(loss)

loss = L(W, X, b, y)
print(loss)

loss.backward() # ***** 이거 하면 알아서 W에 대한 기울기, b에 대한 기울기
print(W.grad)
print(b.grad)
# Out:
# tensor(1.4500, grad_fn=<MeanBackward0>)
# tensor([[6.7000, 8.3000, 9.9000]])
# tensor([1.6000])

# %% [markdown]
# ## 07.Gradient Descent 가중치 업데이트 방식 비교
#
#
# | 방식                | 설명                | 특징           |
# | ----------------- | ----------------- | ------------ |
# | **Batch GD**      | 전체 데이터로 한 번에 업데이트 | 가장 안정적, 느림   |
# | **Mini-Batch GD** | 일부 데이터(배치)마다 업데이트 | 일반적인 학습 방식   |
# | **SGD**           | 한 데이터마다 바로 업데이트   | 노이즈 큼, 빠른 반응 |
#
#
#
#
# **공통 조건**
#
#
# * 문제: 단순 선형 회귀 $y = wx + b$
# * 손실: MSE (평균제곱오차)
# * 데이터: 임의의 간단한 샘플로 구성 (2차원 입력, 100개 샘플)

# %% [markdown]
# ### tensor 직접 제어
#
# - BGD
# - Mini-batch GD
# - SGD

# %%
# 데이터 생성
torch.manual_seed(42)

X = torch.randn(100, 2)
W_true = torch.tensor([[2.0, -3.0]])
b_true = torch.tensor([5.0])
y = X @ W_true.T + b_true + torch.randn(100, 1) * 0.5


print(X.shape, y.shape)
# Out:
# torch.Size([100, 2]) torch.Size([100, 1])

# %%
# 1. BGD
W = torch.zeros(1, 2, requires_grad=True)
b = torch.zeros(1, requires_grad=True)

lr = 0.1

for epoch in range(20):
    y_hat = X @ W.T + b
    loss = torch.mean((y_hat - y) ** 2) # 스칼라
    loss.backward()

    # 최적화함수 대신 직접 갱신
    with torch.no_grad() :
        W -= lr * W.grad
        b -= lr * b.grad

        W.grad.zero_() # 메소드_형식일때는 in-place 처리 W.grad = W.grad.zero()
                    # 원래는 직접 주입 시켜줘야 하는데, 좀 간단하게 쓸 수 있는 방법이다!
        b.grad.zero_()

    print(f'epoch: {epoch + 1}, loss: {loss.item():4f}')
# Out:
# epoch: 1, loss: 26.907991
# epoch: 2, loss: 19.797335
# epoch: 3, loss: 14.713387
# epoch: 4, loss: 11.029496
# epoch: 5, loss: 8.329667
# epoch: 6, loss: 6.332347
# epoch: 7, loss: 4.843369
# epoch: 8, loss: 3.726490
# epoch: 9, loss: 2.884600
# epoch: 10, loss: 2.247530
# epoch: 11, loss: 1.763981
# epoch: 12, loss: 1.396084
# epoch: 13, loss: 1.115659
# epoch: 14, loss: 0.901599
# epoch: 15, loss: 0.738015
# epoch: 16, loss: 0.612897
# epoch: 17, loss: 0.517133
# epoch: 18, loss: 0.443799
# epoch: 19, loss: 0.387618
# epoch: 20, loss: 0.344564

# %%
# 2. Mini-batch 방식
W = torch.zeros(1, 2, requires_grad=True)
b = torch.zeros(1, requires_grad=True)

lr = 0.1
batch_size = 20 # 100개의 샘플을 20개씩 5번 처리 (하나의 epoch당)

for epoch in range(20):
    indices = torch.randperm(X.size(0)) # X.size(0) == 100
    #print(indices.numpy())

    for i in range(0, X.size(0), batch_size): # 가중치랑 절편 알기 위해서
        batch_index = indices[i: i + batch_size]
        # print('           ', batch_index.numpy())
        X_batch = X[batch_index]
        y_batch = y[batch_index]

        y_hat = X_batch @ W.T + b
        loss = torch.mean((y_hat - y_batch) ** 2)

        loss.backward()

        with torch.no_grad():
            # 기울기 갱신
            W -= lr * W.grad
            b -= lr * b.grad

            # 기울기 초기화
            W.grad.zero_()
            b.grad.zero_()

    print(f'epoch {epoch + 1} : loss {loss.item():4f}')
# Out:
# epoch 1 : loss 6.813109
# epoch 2 : loss 2.998341
# epoch 3 : loss 0.779806
# epoch 4 : loss 0.375116
# epoch 5 : loss 0.281189
# epoch 6 : loss 0.186157
# epoch 7 : loss 0.194360
# epoch 8 : loss 0.142639
# epoch 9 : loss 0.197583
# epoch 10 : loss 0.214594
# epoch 11 : loss 0.176423
# epoch 12 : loss 0.214267
# epoch 13 : loss 0.253670
# epoch 14 : loss 0.328991
# epoch 15 : loss 0.189103
# epoch 16 : loss 0.178879
# epoch 17 : loss 0.259712
# epoch 18 : loss 0.272574
# epoch 19 : loss 0.229838
# epoch 20 : loss 0.213572

# %%
# 3. SGD 확률적 경사하강법
# batch_size = 1인 미니배치 경사하강법
W = torch.zeros(1, 2, requires_grad=True)
b = torch.zeros(1, requires_grad=True)

lr = 0.1

for epoch in range(20):
    indices = torch.randperm(X.size(0)) # 데이터 샘플 수

    for i in indices:
        X_i = X[i]
        y_i = y[i]

        y_hat = X_i @ W.T + b
        loss = torch.mean((y_hat - y_i) ** 2)

        loss.backward()

        with torch.no_grad():
            # 기울기 갱신
            W -= lr * W.grad
            b -= lr * b.grad

            # 기울기 초기화
            W.grad.zero_()
            b.grad.zero_()

    print(f'epoch {epoch + 1} : loss {loss.item():4f}')
# Out:
# epoch 1 : loss 0.000100
# epoch 2 : loss 0.813070
# epoch 3 : loss 0.509737
# epoch 4 : loss 0.081824
# epoch 5 : loss 0.200389
# epoch 6 : loss 0.244128
# epoch 7 : loss 0.309414
# epoch 8 : loss 0.331610
# epoch 9 : loss 0.003295
# epoch 10 : loss 0.322557
# epoch 11 : loss 0.175953
# epoch 12 : loss 0.106600
# epoch 13 : loss 1.069683
# epoch 14 : loss 1.058720
# epoch 15 : loss 0.007500
# epoch 16 : loss 0.207045
# epoch 17 : loss 0.164256
# epoch 18 : loss 0.109542
# epoch 19 : loss 0.004170
# epoch 20 : loss 0.060047

# %% [markdown]
# # DataSet / DataLoader
# - BGD
# - Mini-batch GD
# - SGD

# %%
# 데이터 생성
X = torch.linspace(0, 10, 100).unsqueeze(1) # 0부터 10까지 균등한 값 100개 뽑아줘
y = 3 * X + 1 + torch.randn_like(X) * 0.5
print(X)
# Out:
# tensor([[ 0.0000],
#         [ 0.1010],
#         [ 0.2020],
#         [ 0.3030],
#         [ 0.4040],
#         [ 0.5051],
#         [ 0.6061],
#         [ 0.7071],
#         [ 0.8081],
#         [ 0.9091],
#         [ 1.0101],
#         [ 1.1111],
#         [ 1.2121],
#         [ 1.3131],
#         [ 1.4141],
#         [ 1.5152],
#         [ 1.6162],
#         [ 1.7172],
#         [ 1.8182],
#         [ 1.9192],
#         [ 2.0202],
#         [ 2.1212],
#         [ 2.2222],
#         [ 2.3232],
#         [ 2.4242],
#         [ 2.5253],
#         [ 2.6263],
#         [ 2.7273],
#         [ 2.8283],
#         [ 2.9293],
#         [ 3.0303],
#         [ 3.1313],
#         [ 3.2323],
#         [ 3.3333],
#         [ 3.4343],
#         [ 3.5354],
#         [ 3.6364],
#         [ 3.7374],
#         [ 3.8384],
#         [ 3.9394],
#         [ 4.0404],
#         [ 4.1414],
#         [ 4.2424],
#         [ 4.3434],
#         [ 4.4444],
#         [ 4.5455],
#         [ 4.6465],
#         [ 4.7475],
#         [ 4.8485],
#         [ 4.9495],
#         [ 5.0505],
#         [ 5.1515],
#         [ 5.2525],
#         [ 5.3535],
#         [ 5.4545],
#         [ 5.5556],
#         [ 5.6566],
#         [ 5.7576],
#         [ 5.8586],
#         [ 5.9596],
#         [ 6.0606],
#         [ 6.1616],
#         [ 6.2626],
#         [ 6.3636],
#         [ 6.4646],
#         [ 6.5657],
#         [ 6.6667],
#         [ 6.7677],
#         [ 6.8687],
#         [ 6.9697],
#         [ 7.0707],
#         [ 7.1717],
#         [ 7.2727],
#         [ 7.3737],
#         [ 7.4747],
#         [ 7.5758],
#         [ 7.6768],
#         [ 7.7778],
#         [ 7.8788],
#         [ 7.9798],
#         [ 8.0808],
#         [ 8.1818],
#         [ 8.2828],
#         [ 8.3838],
#         [ 8.4848],
#         [ 8.5859],
#         [ 8.6869],
#         [ 8.7879],
#         [ 8.8889],
#         [ 8.9899],
#         [ 9.0909],
#         [ 9.1919],
#         [ 9.2929],
#         [ 9.3939],
#         [ 9.4949],
#         [ 9.5960],
#         [ 9.6970],
#         [ 9.7980],
#         [ 9.8990],
#         [10.0000]])

# %%
# 데이터셋 클래스
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset


class MyDataset(Dataset):
    # Dataset 상속 시 len, getitem 필수 작성
    def __init__(self, X, y):
        super().__init__()
        self.X = X
        self.y = y
    def __len__(self):
        """전체 데이터 수를 반환"""
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

dataset = MyDataset(X, y)

model = nn.Linear(1, 1)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.01)

# %%
# 1. BGD
from torch.utils.data import DataLoader

dataloader = DataLoader(dataset, batch_size=len(dataset), shuffle=True)
model = nn.Linear(1, 1)
optimizer = optim.Adam(model.parameters(), lr=0.01)

for epoch in range(200):
    for X_batch, y_batch in dataloader : # 200번 반복 200번 업데이트
        # print(X_batch, y_batch)
        optimizer.zero_grad()
        pred = model(X_batch)
        loss = criterion(pred, y_batch)
        loss.backward()
        optimizer.step()
    print(f'Epoch {epoch + 1} : Loss {loss.item():4f}')

# %%
# 2. Mini-batch
from torch.utils.data import DataLoader
                                    # 얘만 바꿔주면 됨 샘플이 100개 있는데 16개씩 자르다가 마지막에 4개가 남으면

# drop_last=True: 마지막 배치개수가 지정한 batchsize보다 작은 경우 버림
dataloader = DataLoader(dataset, batch_size=16, shuffle=True, drop_last=True)
model = nn.Linear(1, 1)
optimizer = optim.Adam(model.parameters(), lr=0.01) # 100/16만큼 반복

for epoch in range(200):
    for X_batch, y_batch in dataloader:
        # print(X_batch, y_batch)
        optimizer.zero_grad()
        pred = model(X_batch)
        loss = criterion(pred, y_batch)
        loss.backward()
        optimizer.step() # 표지판 생겼으니까 다시 갱신해준다.
    print(f'Epoch {epoch + 1} : Loss {loss.item():4f}')
# Out:
# Epoch 1 : Loss 705.655457
# Epoch 2 : Loss 644.711731
# Epoch 3 : Loss 657.981995
# Epoch 4 : Loss 581.659180
# Epoch 5 : Loss 585.426331
# Epoch 6 : Loss 689.755188
# Epoch 7 : Loss 284.238647
# Epoch 8 : Loss 506.900024
# Epoch 9 : Loss 352.683411
# Epoch 10 : Loss 453.859314
# Epoch 11 : Loss 435.826294
# Epoch 12 : Loss 350.235718
# Epoch 13 : Loss 318.844482
# Epoch 14 : Loss 331.164673
# Epoch 15 : Loss 249.885834
# Epoch 16 : Loss 351.260620
# Epoch 17 : Loss 318.810425
# Epoch 18 : Loss 354.406860
# Epoch 19 : Loss 381.382050
# Epoch 20 : Loss 226.204956
# Epoch 21 : Loss 246.202911
# Epoch 22 : Loss 288.291870
# Epoch 23 : Loss 172.305206
# Epoch 24 : Loss 149.681458
# Epoch 25 : Loss 274.814789
# Epoch 26 : Loss 227.738052
# Epoch 27 : Loss 220.583984
# Epoch 28 : Loss 188.793915
# Epoch 29 : Loss 227.110428
# Epoch 30 : Loss 144.225769
# Epoch 31 : Loss 149.198776
# Epoch 32 : Loss 218.343140
# Epoch 33 : Loss 141.790619
# Epoch 34 : Loss 164.396210
# Epoch 35 : Loss 178.024338
# Epoch 36 : Loss 116.282280
# Epoch 37 : Loss 127.553818
# Epoch 38 : Loss 114.536041
# Epoch 39 : Loss 83.454201
# Epoch 40 : Loss 160.315659
# Epoch 41 : Loss 126.984581
# Epoch 42 : Loss 115.319153
# Epoch 43 : Loss 78.473938
# Epoch 44 : Loss 112.117310
# Epoch 45 : Loss 89.137535
# Epoch 46 : Loss 115.468185
# Epoch 47 : Loss 72.934624
# Epoch 48 : Loss 84.724747
# Epoch 49 : Loss 60.486443
# Epoch 50 : Loss 75.616859
# Epoch 51 : Loss 47.363735
# Epoch 52 : Loss 80.215858
# Epoch 53 : Loss 48.497002
# Epoch 54 : Loss 53.064774
# Epoch 55 : Loss 46.336761
# Epoch 56 : Loss 47.201038
# Epoch 57 : Loss 47.063484
# Epoch 58 : Loss 33.591797
# Epoch 59 : Loss 42.799599
# Epoch 60 : Loss 66.373451
# Epoch 61 : Loss 47.690845
# Epoch 62 : Loss 36.880920
# Epoch 63 : Loss 34.549191
# Epoch 64 : Loss 20.338081
# Epoch 65 : Loss 36.986614
# Epoch 66 : Loss 26.947578
# Epoch 67 : Loss 22.007114
# Epoch 68 : Loss 25.379366
# Epoch 69 : Loss 26.428467
# Epoch 70 : Loss 28.788040
# Epoch 71 : Loss 31.780653
# Epoch 72 : Loss 22.648254
# Epoch 73 : Loss 17.973904
# Epoch 74 : Loss 10.545441
# Epoch 75 : Loss 27.329901
# Epoch 76 : Loss 19.856699
# Epoch 77 : Loss 19.045692
# Epoch 78 : Loss 13.564886
# Epoch 79 : Loss 13.147399
# Epoch 80 : Loss 9.018190
# Epoch 81 : Loss 8.549448
# Epoch 82 : Loss 16.090528
# Epoch 83 : Loss 11.634526
# Epoch 84 : Loss 10.341337
# Epoch 85 : Loss 8.736771
# Epoch 86 : Loss 13.457239
# Epoch 87 : Loss 9.613580
# Epoch 88 : Loss 7.458767
# Epoch 89 : Loss 9.166294
# Epoch 90 : Loss 10.575040
# Epoch 91 : Loss 8.406992
# Epoch 92 : Loss 8.468660
# Epoch 93 : Loss 7.314417
# Epoch 94 : Loss 5.553691
# Epoch 95 : Loss 5.251141
# Epoch 96 : Loss 5.352813
# Epoch 97 : Loss 5.313238
# Epoch 98 : Loss 6.836106
# Epoch 99 : Loss 3.558930
# Epoch 100 : Loss 5.820754
# Epoch 101 : Loss 5.736727
# Epoch 102 : Loss 5.048046
# Epoch 103 : Loss 2.564544
# Epoch 104 : Loss 3.212883
# Epoch 105 : Loss 4.534426
# Epoch 106 : Loss 5.157826
# Epoch 107 : Loss 4.062562
# Epoch 108 : Loss 4.692955
# Epoch 109 : Loss 2.089261
# Epoch 110 : Loss 2.591447
# Epoch 111 : Loss 2.678032
# Epoch 112 : Loss 2.808006
# Epoch 113 : Loss 2.282278
# Epoch 114 : Loss 2.365961
# Epoch 115 : Loss 2.390260
# Epoch 116 : Loss 1.382408
# Epoch 117 : Loss 1.999639
# Epoch 118 : Loss 1.746909
# Epoch 119 : Loss 1.515646
# Epoch 120 : Loss 2.495855
# Epoch 121 : Loss 1.155514
# Epoch 122 : Loss 0.793154
# Epoch 123 : Loss 2.439572
# Epoch 124 : Loss 2.069900
# Epoch 125 : Loss 1.675286
# Epoch 126 : Loss 2.269417
# Epoch 127 : Loss 2.188918
# Epoch 128 : Loss 1.911684
# Epoch 129 : Loss 1.309887
# Epoch 130 : Loss 1.724008
# Epoch 131 : Loss 1.747413
# Epoch 132 : Loss 1.422621
# Epoch 133 : Loss 1.902572
# Epoch 134 : Loss 1.354090
# Epoch 135 : Loss 2.394532
# Epoch 136 : Loss 1.570852
# Epoch 137 : Loss 1.272618
# Epoch 138 : Loss 0.831807
# Epoch 139 : Loss 1.258027
# Epoch 140 : Loss 1.314509
# Epoch 141 : Loss 0.898987
# Epoch 142 : Loss 0.958202
# Epoch 143 : Loss 1.251740
# Epoch 144 : Loss 1.211958
# Epoch 145 : Loss 1.141704
# Epoch 146 : Loss 1.535149
# Epoch 147 : Loss 1.165351
# Epoch 148 : Loss 1.096550
# Epoch 149 : Loss 0.653915
# Epoch 150 : Loss 1.164947
# Epoch 151 : Loss 1.042907
# Epoch 152 : Loss 1.591263
# Epoch 153 : Loss 1.249247
# Epoch 154 : Loss 1.665372
# Epoch 155 : Loss 1.234776
# Epoch 156 : Loss 1.774859
# Epoch 157 : Loss 1.054192
# Epoch 158 : Loss 1.300584
# Epoch 159 : Loss 1.283950
# Epoch 160 : Loss 1.293355
# Epoch 161 : Loss 1.627876
# Epoch 162 : Loss 1.107625
# Epoch 163 : Loss 1.019840
# Epoch 164 : Loss 1.653019
# Epoch 165 : Loss 1.980649
# Epoch 166 : Loss 0.942519
# Epoch 167 : Loss 1.274134
# Epoch 168 : Loss 0.711159
# Epoch 169 : Loss 0.993797
# Epoch 170 : Loss 1.045799
# Epoch 171 : Loss 1.199338
# Epoch 172 : Loss 0.752582
# Epoch 173 : Loss 1.265836
# Epoch 174 : Loss 1.391035
# Epoch 175 : Loss 1.525147
# Epoch 176 : Loss 1.306362
# Epoch 177 : Loss 1.559484
# Epoch 178 : Loss 0.959442
# Epoch 179 : Loss 1.242205
# Epoch 180 : Loss 1.241924
# Epoch 181 : Loss 0.684840
# Epoch 182 : Loss 1.423774
# Epoch 183 : Loss 0.632997
# Epoch 184 : Loss 0.976964
# Epoch 185 : Loss 1.678490
# Epoch 186 : Loss 1.200287
# Epoch 187 : Loss 0.965429
# Epoch 188 : Loss 1.640847
# Epoch 189 : Loss 1.556213
# Epoch 190 : Loss 0.907499
# Epoch 191 : Loss 1.035017
# Epoch 192 : Loss 1.134786
# Epoch 193 : Loss 0.702604
# Epoch 194 : Loss 1.370948
# Epoch 195 : Loss 1.248470
# Epoch 196 : Loss 1.325150
# Epoch 197 : Loss 1.195888
# Epoch 198 : Loss 1.106284
# Epoch 199 : Loss 0.694569
# Epoch 200 : Loss 0.711231

# %%
# 3. SGD
from torch.utils.data import DataLoader

dataloader = DataLoader(dataset, batch_size=1, shuffle=True)# 좀더 편하게 테스트 해볼 수 있다.
model = nn.Linear(1, 1)
optimizer = optim.Adam(model.parameters(), lr=0.01)

for epoch in range(200): # 1번 반복에 200번 업데이트
    for X_batch, y_batch in dataloader:
        # print(X_batch, y_batch)
        optimizer.zero_grad()
        pred = model(X_batch)
        loss = criterion(pred, y_batch)
        loss.backward()
        optimizer.step() # 표지판 생겼으니까 다시 갱신해준다.
    print(f'Epoch {epoch + 1} : Loss {loss.item():4f}')
# Out:
# Epoch 1 : Loss 7.732832
# Epoch 2 : Loss 6.242144
# Epoch 3 : Loss 8.667014
# Epoch 4 : Loss 0.152159
# Epoch 5 : Loss 0.114460
# Epoch 6 : Loss 0.439402
# Epoch 7 : Loss 0.938955
# Epoch 8 : Loss 0.036126
# Epoch 9 : Loss 0.237296
# Epoch 10 : Loss 0.050373
# Epoch 11 : Loss 0.021323
# Epoch 12 : Loss 0.004479
# Epoch 13 : Loss 0.016505
# Epoch 14 : Loss 0.003034
# Epoch 15 : Loss 0.415920
# Epoch 16 : Loss 0.451173
# Epoch 17 : Loss 0.073676
# Epoch 18 : Loss 0.073820
# Epoch 19 : Loss 0.387159
# Epoch 20 : Loss 0.621697
# Epoch 21 : Loss 0.037791
# Epoch 22 : Loss 0.049525
# Epoch 23 : Loss 0.282863
# Epoch 24 : Loss 0.040082
# Epoch 25 : Loss 0.067937
# Epoch 26 : Loss 0.510957
# Epoch 27 : Loss 0.049841
# Epoch 28 : Loss 1.242210
# Epoch 29 : Loss 0.070541
# Epoch 30 : Loss 0.450366
# Epoch 31 : Loss 0.690963
# Epoch 32 : Loss 0.421657
# Epoch 33 : Loss 0.111731
# Epoch 34 : Loss 0.056221
# Epoch 35 : Loss 0.303186
# Epoch 36 : Loss 0.359355
# Epoch 37 : Loss 0.214830
# Epoch 38 : Loss 0.117204
# Epoch 39 : Loss 0.056632
# Epoch 40 : Loss 0.469269
# Epoch 41 : Loss 1.675252
# Epoch 42 : Loss 0.078866
# Epoch 43 : Loss 0.031444
# Epoch 44 : Loss 0.012230
# Epoch 45 : Loss 0.020148
# Epoch 46 : Loss 0.037224
# Epoch 47 : Loss 0.018806
# Epoch 48 : Loss 0.445266
# Epoch 49 : Loss 0.009967
# Epoch 50 : Loss 0.374133
# Epoch 51 : Loss 0.600837
# Epoch 52 : Loss 0.003995
# Epoch 53 : Loss 0.803568
# Epoch 54 : Loss 0.143529
# Epoch 55 : Loss 0.185327
# Epoch 56 : Loss 0.022093
# Epoch 57 : Loss 0.000101
# Epoch 58 : Loss 0.060960
# Epoch 59 : Loss 0.038409
# Epoch 60 : Loss 0.051568
# Epoch 61 : Loss 0.189279
# Epoch 62 : Loss 0.026614
# Epoch 63 : Loss 0.038295
# Epoch 64 : Loss 0.113355
# Epoch 65 : Loss 0.025635
# Epoch 66 : Loss 1.081173
# Epoch 67 : Loss 1.320587
# Epoch 68 : Loss 0.052674
# Epoch 69 : Loss 0.088785
# Epoch 70 : Loss 0.775791
# Epoch 71 : Loss 0.035254
# Epoch 72 : Loss 1.162600
# Epoch 73 : Loss 0.512746
# Epoch 74 : Loss 0.610636
# Epoch 75 : Loss 0.923808
# Epoch 76 : Loss 0.055302
# Epoch 77 : Loss 0.192329
# Epoch 78 : Loss 0.234919
# Epoch 79 : Loss 0.165094
# Epoch 80 : Loss 0.041820
# Epoch 81 : Loss 0.119983
# Epoch 82 : Loss 0.306616
# Epoch 83 : Loss 0.298804
# Epoch 84 : Loss 0.305772
# Epoch 85 : Loss 0.097149
# Epoch 86 : Loss 0.342145
# Epoch 87 : Loss 0.001522
# Epoch 88 : Loss 0.055599
# Epoch 89 : Loss 0.601816
# Epoch 90 : Loss 0.000507
# Epoch 91 : Loss 0.062396
# Epoch 92 : Loss 0.000541
# Epoch 93 : Loss 0.648926
# Epoch 94 : Loss 0.258604
# Epoch 95 : Loss 0.119372
# Epoch 96 : Loss 0.198026
# Epoch 97 : Loss 0.135567
# Epoch 98 : Loss 0.008665
# Epoch 99 : Loss 0.127357
# Epoch 100 : Loss 0.119166
# Epoch 101 : Loss 0.051489
# Epoch 102 : Loss 0.062578
# Epoch 103 : Loss 0.023562
# Epoch 104 : Loss 0.000477
# Epoch 105 : Loss 0.011977
# Epoch 106 : Loss 0.061861
# Epoch 107 : Loss 0.013074
# Epoch 108 : Loss 0.521992
# Epoch 109 : Loss 0.128459
# Epoch 110 : Loss 0.000131
# Epoch 111 : Loss 0.101411
# Epoch 112 : Loss 0.542241
# Epoch 113 : Loss 0.265413
# Epoch 114 : Loss 0.613748
# Epoch 115 : Loss 0.002342
# Epoch 116 : Loss 0.147356
# Epoch 117 : Loss 0.000603
# Epoch 118 : Loss 0.256995
# Epoch 119 : Loss 0.443854
# Epoch 120 : Loss 0.008479
# Epoch 121 : Loss 0.181210
# Epoch 122 : Loss 0.004018
# Epoch 123 : Loss 0.119156
# Epoch 124 : Loss 0.003529
# Epoch 125 : Loss 0.278251
# Epoch 126 : Loss 0.050626
# Epoch 127 : Loss 0.042223
# Epoch 128 : Loss 0.279002
# Epoch 129 : Loss 0.383951
# Epoch 130 : Loss 0.543653
# Epoch 131 : Loss 0.028460
# Epoch 132 : Loss 0.135354
# Epoch 133 : Loss 0.055946
# Epoch 134 : Loss 0.003089
# Epoch 135 : Loss 0.067522
# Epoch 136 : Loss 0.393860
# Epoch 137 : Loss 0.027474
# Epoch 138 : Loss 0.008903
# Epoch 139 : Loss 0.322292
# Epoch 140 : Loss 0.232494
# Epoch 141 : Loss 0.028847
# Epoch 142 : Loss 0.198715
# Epoch 143 : Loss 0.010880
# Epoch 144 : Loss 0.219894
# Epoch 145 : Loss 0.161390
# Epoch 146 : Loss 0.219717
# Epoch 147 : Loss 0.008184
# Epoch 148 : Loss 0.801921
# Epoch 149 : Loss 0.054870
# Epoch 150 : Loss 0.224563
# Epoch 151 : Loss 0.083057
# Epoch 152 : Loss 0.049401
# Epoch 153 : Loss 0.031810
# Epoch 154 : Loss 0.035879
# Epoch 155 : Loss 0.003825
# Epoch 156 : Loss 0.003235
# Epoch 157 : Loss 0.001752
# Epoch 158 : Loss 0.057662
# Epoch 159 : Loss 0.009779
# Epoch 160 : Loss 0.270091
# Epoch 161 : Loss 0.529455
# Epoch 162 : Loss 0.009595
# Epoch 163 : Loss 0.252783
# Epoch 164 : Loss 0.375543
# Epoch 165 : Loss 0.204597
# Epoch 166 : Loss 0.248644
# Epoch 167 : Loss 0.566633
# Epoch 168 : Loss 0.004992
# Epoch 169 : Loss 0.161502
# Epoch 170 : Loss 0.000176
# Epoch 171 : Loss 0.012125
# Epoch 172 : Loss 0.088138
# Epoch 173 : Loss 0.180030
# Epoch 174 : Loss 1.114020
# Epoch 175 : Loss 0.739877
# Epoch 176 : Loss 0.004178
# Epoch 177 : Loss 0.472002
# Epoch 178 : Loss 0.270460
# Epoch 179 : Loss 0.015633
# Epoch 180 : Loss 0.276358
# Epoch 181 : Loss 0.068682
# Epoch 182 : Loss 0.086587
# Epoch 183 : Loss 0.024678
# Epoch 184 : Loss 0.074702
# Epoch 185 : Loss 0.171843
# Epoch 186 : Loss 0.176947
# Epoch 187 : Loss 0.019272
# Epoch 188 : Loss 0.006011
# Epoch 189 : Loss 0.004245
# Epoch 190 : Loss 0.796621
# Epoch 191 : Loss 0.042094
# Epoch 192 : Loss 0.000005
# Epoch 193 : Loss 0.227230
# Epoch 194 : Loss 0.066504
# Epoch 195 : Loss 0.016702
# Epoch 196 : Loss 0.096980
# Epoch 197 : Loss 0.185938
# Epoch 198 : Loss 1.495985
# Epoch 199 : Loss 0.110678
# Epoch 200 : Loss 0.013780

# %% [markdown]
# # 08. 손글씨 분류 MINIST

# %%
# 데이터 로드
# 깃이그노어에 추가 : /**/MNIST/raw/
from torchvision import datasets, transforms

transforms = transforms.Compose([
    transforms.ToTensor(), # ndarray, PIL이미지 타입 등을 tensor타입으로 변환 (0~1 스케일링)
    # (픽셀값 - 평균) / 표준편차 -> 값의 범위를 -1~1
    transforms.Normalize((0.5), (0.5)) # 입력데이터(0~1)에 대한 정규화 (평균0, 표준편차1)
])

train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transforms)
test_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=transforms) # 테스트라서

batch_size = 64
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# 평가/검증 데이터는 순서를 섞지 않는다.
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
# 데이터 확인
print(len(train_dataset)) # 60000
print(len(test_dataset)) # 10000

for images, labels in train_loader:
    print(images.shape, labels.shape)
    image = images[0]
    image = image.flatten() # 차원을 쭉쭉 펴줌 쭉 피게 되면 784개가 나옴
    print(image.shape)
    print(labels[:10])
    break
# Out:
# 60000
# 10000
# torch.Size([64, 1, 28, 28]) torch.Size([64])
# torch.Size([784])
# tensor([3, 9, 9, 3, 7, 3, 4, 0, 2, 0])

# %%
# 모델 생성
class MNISTNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            nn.Flatten(),
            nn.Linear(28 * 28, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 10), # 손글씨 분류 데이터 종류가 10개라서 10개만 됨
        )

    def forward(self, x):
        return self.net(x)

model = MNISTNet()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
# 모델 학습
model.train()  #training = True 기본값
print(model.training)

for epoch in range(10): # 에포크 한 번이라는 건 학습데이터 전체를 한 번 사용한다.
    for X_batch, y_batch in train_loader:
        optimizer.zero_grad()
        logits = model(X_batch) # 10개 클래스에 대한 로짓값
        loss = criterion(logits, y_batch) # 로스를 줄이는 방향으로 가중치 업데이트
        loss.backward()
        optimizer.step() # 가중치 갱신

    print(f'Epoch {epoch + 1} : Loss {loss.item():.4f}')
# Out:
# True
# Epoch 1 : Loss 0.2875
# Epoch 2 : Loss 0.2985
# Epoch 3 : Loss 0.0460
# Epoch 4 : Loss 0.0818
# Epoch 5 : Loss 0.0893
# Epoch 6 : Loss 0.1852
# Epoch 7 : Loss 0.0405
# Epoch 8 : Loss 0.0944
# Epoch 9 : Loss 0.0124
# Epoch 10 : Loss 0.1344

# %%
import torch.nn.functional as F
from sklearn.metrics import accuracy_score

# 모델 평가
model.eval() # eval모드 키면 True였는데 False 됨
print(model.training) # False


all_preds = []
all_y = []
all_X = []

with torch.no_grad():
    for X_batch, y_batch in test_loader:
        logits = model(X_batch)
        p = F.softmax(logits, dim=1) # logits을 뱉어내니까 행끼리의 확률을 뱉어준다.
        pred = p.argmax(dim=1)  # 나는 확률이 필요한게 아니라 숫자가 필요한데? 그 중에서 가장 큰 값 인덱스 번호 줘봐
        all_preds.extend(pred)
        all_X.extend(X_batch)
        all_y.extend(y_batch)

print(len(all_preds), len(all_y), len(all_X))
print('정확도 :', accuracy_score(all_y, all_preds))
# Out:
# False
# 10000 10000 10000
# 정확도 : 0.9729

# %%
# import matplotlib.pyplot as plt
# 시각화
num_images = 10
indices = np.random.choice(len(all_X), num_images, replace=False) # 중복된 값은 뽑지 X (비복원추출)

plt.figure(figsize=(15, 3))

for i, idx in enumerate(indices):
    image = all_X[idx].squeeze()
    label = all_y[idx]
    pred = all_preds[idx]

    plt.subplot(1, num_images, i + 1)
    plt.imshow(image, cmap='gray') # _r 하면 반전
    plt.title(f'label : {label}\nPred: {pred}')
    plt.axis('off')

plt.show() # 숫자는 밝을 수록 높다.

# %%
# 예측이 틀린 손글씨 시각화

num_images = 10
indices = [i for i in range(len(all_X)) if all_preds[i] != all_y[i]]
# all_X의 길이만큼 반복하면서 예측값이랑 정답이랑 다른 것만 i만큼 뽑겠다.
indices = indices[:num_images]

plt.figure(figsize=(15, 3))
for i, idx in enumerate(indices):
    image = all_X[idx].squeeze()
    label = all_y[idx]
    pred = all_preds[idx]

    plt.subplot(1, num_images, i + 1)
    plt.imshow(image, cmap='gray')
    plt.title(f'Label : {label}\nPred : {pred}')
    plt.axis('off')

plt.show()# 숫자는 밝을 수록 높다.
